# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyankansd/IT-496/blob/main/A6_Psiddap_radarcharts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import math
AA=pd.DataFrame(columns=['criteria', 'weight', 'ratingA', 'ratingB', 'scoreA','scoreB'])
print(AA)
# Out:
# Empty DataFrame
# Columns: [criteria, weight, ratingA, ratingB, scoreA, scoreB]
# Index: []

# %%
AA['criteria']=['Projectrisk','UnverifiableRequirements','InvalidAssumptions','LackofTracebility','WrongStakeholders']
print(AA)
# Out:
#                    criteria weight ratingA ratingB scoreA scoreB
# 0               Projectrisk    NaN     NaN     NaN    NaN    NaN
# 1  UnverifiableRequirements    NaN     NaN     NaN    NaN    NaN
# 2        InvalidAssumptions    NaN     NaN     NaN    NaN    NaN
# 3         LackofTracebility    NaN     NaN     NaN    NaN    NaN
# 4         WrongStakeholders    NaN     NaN     NaN    NaN    NaN

# %%
AA['weight']=[0.5,0.1,0.3,.2,0.5]
print(AA)
# Out:
#                    criteria  weight ratingA ratingB scoreA scoreB
# 0               Projectrisk     0.5     NaN     NaN    NaN    NaN
# 1  UnverifiableRequirements     0.1     NaN     NaN    NaN    NaN
# 2        InvalidAssumptions     0.3     NaN     NaN    NaN    NaN
# 3         LackofTracebility     0.2     NaN     NaN    NaN    NaN
# 4         WrongStakeholders     0.5     NaN     NaN    NaN    NaN

# %%
AA['ratingA']=[5,11,6,4,2]
AA['ratingB']=[5,4,8,6,3]
print(AA)
# Out:
#                    criteria  weight  ratingA  ratingB scoreA scoreB
# 0               Projectrisk     0.5        5        5    NaN    NaN
# 1  UnverifiableRequirements     0.1       11        4    NaN    NaN
# 2        InvalidAssumptions     0.3        6        8    NaN    NaN
# 3         LackofTracebility     0.2        4        6    NaN    NaN
# 4         WrongStakeholders     0.5        2        3    NaN    NaN

# %%
for index, row in AA.iterrows():
  AA['scoreA'][index]=row['ratingA']*row['weight']
  AA['scoreB'][index]=row['ratingB']*row['weight']
  
print(AA)
# Out:
#                    criteria  weight  ratingA  ratingB scoreA scoreB
# 0               Projectrisk     0.5        5        5    2.5    2.5
# 1  UnverifiableRequirements     0.1       11        4    1.1    0.4
# 2        InvalidAssumptions     0.3        6        8    1.8    2.4
# 3         LackofTracebility     0.2        4        6    0.8    1.2
# 4         WrongStakeholders     0.5        2        3    1.0    1.5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
totalScoreA=0
totalScoreB=0
for index, row in AA.iterrows():
  totalScoreA+=row['scoreA']
  totalScoreB+=row['scoreB']

print ('the total score for A 1s {:.2f} and for B is {:.2f}'.format (totalScoreA, totalScoreB))
# Out:
# the total score for A 1s 7.20 and for B is 8.00

# %%
import numpy as np
import matplotlib.pyplot as plt
axisLocations = np.linspace(start=0, stop=2 * np.pi, num=len(AA['ratingA']), endpoint=False)
axisLocations = np.concatenate((axisLocations,[axisLocations[0]]))
ratingsA=AA['ratingA']
ratingsB=AA['ratingB']
ratingsACircular=np.concatenate((ratingsA,[ratingsA[0]]))
ratingsBCircular=np.concatenate((ratingsB,[ratingsB[0]]))
plt.figure(figsize=(8,8))
plt.subplot(polar=True)
plt.plot(axisLocations,ratingsACircular,'r-', linewidth=2, label='In-house development')
plt.plot(axisLocations,ratingsBCircular,'y-', linewidth=2, label='outsource')
plt.title('Project options comparison', size=20)
lines, labels =plt.thetagrids(np.degrees(axisLocations), labels=AA['criteria'])
plt.legend()
plt.show()
